# %% [markdown]
# ### Intro to the Roman Pipeline

# %% [markdown]
# #### Outline
#
# - Pipeline installation and setup
# - Running the pipeline
# - Exercise
# - CRDS
# - Feedback and discussion

# %% [markdown]
# ### Roman pipeline installation and setup up

# %% [markdown]
# The Roman pipeline package is a Python package, called `romancal`. The code is available on [GitHub](https://github.com/spacetelescope/romancal) and releases are posted on [PyPi](https://pypi.org/project/romancal/). Before running the Roman pipeline make sure `romancal` and all its dependencies are installed. The latest installation instructions are available in the [README](https://github.com/spacetelescope/romancal/blob/main/README.md) file on github, and briefly mentioned below.
#
# Public releases are installed directly from PyPI using
#
# ```
# % pip install romancal
# ```
# This installs the pipeline and all its dependencies in the current Python environment. We recommend to use conda as a basis for managing the environments and that new releases are installed in new conda environments.
#
# The development version of the pipeline can be installed using the command:
#
# ```
# % pip install git+https://github.com/spacetelescope/romancal.git
# ```
#
# This will install the code from the main development branch and all its current dependencies.
#
# In addition, we recommend that jupyter and ipython are installed as well. They are not dependencies, just convenience.
#
# The pipeline uses reference stored in the [Calibration Reference Data System (CRDS)](https://roman-crds.stsci.edu/). We don't have a public CRDS server for Roman yet so examples in this notebook while showing how to use a server when it is available, will use local reference files.
#
# **Pipeline documentation** is available publicly on [readthedocs](https://roman-pipeline.readthedocs.io/en/latest/).

# %% [markdown]
# #### CRDS configuration
#
# To run the pipeline outside the STScI network, CRDS must be configured by setting two environment variables:
#
# ```
# export CRDS_PATH=$HOME/crds_cache
# export CRDS_SERVER_URL=https://roman-crds.stsci.edu
# ```
#
# ### The CRDS variables need to be set in the environment before starting the notebook.

# %% [markdown]
# #### Running the Roman Pipeline
#
# The pipeline can be run on the command line or in a python session. We'll look first at how to run it in Python. But first, let's download some data.

# %% [markdown]
# #### Stages of the Roman pipeline
#
# The Roman calibration pipeline is split into three stages
#
# - Level2 pipeline, or Exposure Level Pipeline (ELP)
#
#   This stage runs on individual exposures and applies detector-level corrections to given exposure types (imaging, prism, and grism.). The currently implemented steps are listed [here](https://roman-pipeline.readthedocs.io/en/latest/roman/pipeline/exposure_pipeline.html#exposure-pipeline).
#
#
# - Level 3 pipeline, or High Level Pipeline (HLP)
#
#   The Level 3 pipeline combines individual exposures according to the association rules supplied (image only). The currently implemented steps are listed [here](https://roman-pipeline.readthedocs.io/en/latest/roman/pipeline/mosaic_pipeline.html).
#
#
# - Level 4 pipeline
#
#
#   This generates high level products, like various types of catalogs.

# %% [markdown]
# **Steps in a Pipeline stage**
#
# Every stage consistes of one or more steps which run in a sequence. The `ExposurePipeline` currently defines the following steps:
#
# ```
# step_defs: ClassVar = {
#     "dq_init": dq_init_step.DQInitStep,
#     "saturation": SaturationStep,
#     "refpix": RefPixStep,
#     "dark_decay": DarkDecayStep,
#     "wfi18_transient": WFI18TransientStep,
#     "linearity": LinearityStep,
#     "dark_current": DarkCurrentStep,
#     "rampfit": ramp_fit_step.RampFitStep,
#     "assign_wcs": AssignWcsStep,
#     "flatfield": FlatFieldStep,
#     "photom": PhotomStep,
#     "source_catalog": SourceCatalogStep,
#     "tweakreg": TweakRegStep,
# }
#
# ```

# %% [markdown]
# #### Data files naming conventions

# %% [markdown]
# File names are constructed using the following rules:
#
# **WFI detector Level 1 files**
#
# These are uncalibrated files, the standard suffix is `uncal`:
# ```
# rPPPPPCCAAASSSOOOVVV_eeee_<detector>_<optical_element>_uncal.asdf
# ```
#
# **WFI detector Level 2 files**
#
# These are pixel calibrated files, the standard suffix is `cal`:
#
# ```
# rPPPPPCCAAASSSOOOVVV_eeee_<detector>_<optical_element>_cal.asdf
# ```
#
# `PPPPP`: Program number
#
# `CC`:    Execution plan number
#
# `AAA`:   Pass number (with execution plan)
#
# `SSS`:   Segment Number (within pass)
#
# `OOO`:   Observation number
#
# `VVV`:   Visit number
#
# `eeee`:  Exposure number (within the visit)

# %% [markdown]
# #### Running the ELP pipeline from a Python session

# %% [markdown]
# Using `call` is the recommended way to run the pipeline in a Python session. In this case the output data model is returned in memory and can be saved to disk either by passing an option to the `call` method or in a separate command:

# %%
from romancal.pipeline import ExposurePipeline

# %%
# Is there a way to pass a parameter to call?
out = ExposurePipeline.call('../data/r0000101001001001001_0001_wfi01_f158_uncal.asdf',
                            save_results=True)
# Out:
# 2026-09-19 19:46:45,650 - stpipe.step - INFO - ExposurePipeline instance created.
# 2026-09-19 19:46:45,652 - stpipe.step - INFO - DQInitStep instance created.
# 2026-09-19 19:46:45,653 - stpipe.step - INFO - SaturationStep instance created.
# 2026-09-19 19:46:45,654 - stpipe.step - INFO - RefPixStep instance created.
# 2026-09-19 19:46:45,655 - stpipe.step - INFO - DarkDecayStep instance created.
# 2026-09-19 19:46:45,656 - stpipe.step - INFO - WFI18TransientStep instance created.
# 2026-09-19 19:46:45,657 - stpipe.step - INFO - LinearityStep instance created.
# 2026-09-19 19:46:45,657 - stpipe.step - INFO - DarkCurrentStep instance created.
# 2026-09-19 19:46:45,659 - stpipe.step - INFO - RampFitStep instance created.
# 2026-09-19 19:46:45,660 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-09-19 19:46:45,660 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-09-19 19:46:45,661 - stpipe.step - INFO - PhotomStep instance created.
# 2026-09-19 19:46:45,662 - stpipe.step - INFO - SourceCatalogStep instance created.
# 2026-09-19 19:46:45,663 - stpipe.step - INFO - TweakRegStep instance created.
# 2026-09-19 19:46:45,733 - stpipe.step - INFO - Step ExposurePipeline running with args ('../data/r0000101001001001001_0001_wfi01_f158_uncal.asdf',).
# 2026-09-19 19:46:45,760 - stpipe.step - INFO - Step ExposurePipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: None
#   output_ext: .asdf
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: cal
#   search_output_file: True
#   input_dir: ''
#   update_version: False
#   on_disk: False
#   steps:
#     dq_init:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#       expand_gw_flagging: 0
#     saturation:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#       n_pix_grow_sat: 0
#       backup: 0
#     refpix:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#       remove_offset: True
#       remove_trends: True
#       cosine_interpolate: True
#       fft_interpolate: True
#     dark_decay:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#     wfi18_transient:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#       mask_rows: False
#     linearity:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#     dark_current:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#     rampfit:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: rampfit
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#       algorithm: likely
#       rejection_threshold: 4.5
#       use_ramp_jump_detection: True
#       threshold_intercept: None
#       threshold_constant: None
#       include_var_rnoise: False
#       record_jumps: True
#       maximum_cores: '1'
#       expand_large_events: False
#       min_sat_area: 1.0
#       min_jump_area: 6.0
#       expand_factor: 1.9
#       sat_required_snowball: True
#       min_sat_radius_extend: 0.5
#       sat_expand: 2
#       edge_size: 0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#     flatfield:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#       include_var_flat: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#     source_catalog:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: cat
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#       bkg_boxsize: 1000
#       kernel_fwhm: 2.0
#       snr_threshold: 3.0
#       npixels: 25
#       deblend: False
#       fit_psf: True
#       forced_segmentation: ''
#     tweakreg:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .asdf
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       update_version: False
#       catalog_format: ascii.ecsv
#       catalog_path: ''
#       enforce_user_order: False
#       expand_refcat: False
#       minobj: 10
#       searchrad: 2.0
#       use2dhist: True
#       separation: 1.0
#       tolerance: 0.7
#       fitgeometry: general
#       nclip: 3
#       sigma: 3.0
#       abs_refcat: GAIADR3_S3
#       save_abs_catalog: False
#       abs_minobj: 10
#       abs_searchrad: 6.0
#       abs_use2dhist: True
#       abs_separation: 1.0
#       abs_tolerance: 0.7
#       abs_fitgeometry: general
#       abs_nclip: 3
#       abs_sigma: 3.0
#       update_source_catalog_coordinates: False
#       vo_timeout: 1200.0
# 2026-09-19 19:46:45,798 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'r0000101001001001001_0001_wfi01_f158_uncal.asdf' reftypes = ['apcorr', 'dark', 'darkdecaysignal', 'distortion', 'flat', 'gain', 'integralnonlinearity', 'inverselinearity', 'linearity', 'mask', 'photom', 'readnoise', 'refpix', 'saturation']
# 2026-09-19 19:46:46,998 - stpipe.pipeline - INFO - Prefetch for APCORR reference file is '/grp/crds/cache/references/roman/roman_wfi_apcorr_0020.asdf'.
# 2026-09-19 19:46:47,018 - stpipe.pipeline - INFO - Prefetch for DARK reference file is '/grp/crds/cache/references/roman/roman_wfi_dark_0627.asdf'.
# 2026-09-19 19:46:47,037 - stpipe.pipeline - INFO - Prefetch for DARKDECAYSIGNAL reference file is '/grp/crds/cache/references/roman/roman_wfi_darkdecaysignal_0001.asdf'.
# 2026-09-19 19:46:47,056 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/grp/crds/cache/references/roman/roman_wfi_distortion_0014.asdf'.
# 2026-09-19 19:46:47,244 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/grp/crds/cache/references/roman/roman_wfi_flat_0166.asdf'.
# 2026-09-19 19:46:47,272 - stpipe.pipeline - INFO - Prefetch for GAIN reference file is '/grp/crds/cache/references/roman/roman_wfi_gain_0044.asdf'.
# 2026-09-19 19:46:47,299 - stpipe.pipeline - INFO - Prefetch for INTEGRALNONLINEARITY reference file is '/grp/crds/cache/references/roman/roman_wfi_integralnonlinearity_0003.asdf'.
# 2026-09-19 19:46:47,320 - stpipe.pipeline - INFO - Prefetch for INVERSELINEARITY reference file is '/grp/crds/cache/references/roman/roman_wfi_inverselinearity_0042.asdf'.
# 2026-09-19 19:46:47,339 - stpipe.pipeline - INFO - Prefetch for LINEARITY reference file is '/grp/crds/cache/references/roman/roman_wfi_linearity_0039.asdf'.
# 2026-09-19 19:46:47,361 - stpipe.pipeline - INFO - Prefetch for MASK reference file is '/grp/crds/cache/references/roman/roman_wfi_mask_0030.asdf'.
# 2026-09-19 19:46:47,380 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/grp/crds/cache/references/roman/roman_wfi_photom_0040.asdf'.
# 2026-09-19 19:46:47,399 - stpipe.pipeline - INFO - Prefetch for READNOISE reference file is '/grp/crds/cache/references/roman/roman_wfi_readnoise_0051.asdf'.
# 2026-09-19 19:46:47,570 - stpipe.pipeline - INFO - Prefetch for REFPIX reference file is '/grp/crds/cache/references/roman/roman_wfi_refpix_0025.asdf'.
# 2026-09-19 19:46:47,594 - stpipe.pipeline - INFO - Prefetch for SATURATION reference file is '/grp/crds/cache/references/roman/roman_wfi_saturation_0031.asdf'.
# 2026-09-19 19:46:47,618 - romancal.pipeline.exposure_pipeline - INFO - Starting Roman exposure calibration pipeline ...
# 2026-09-19 19:46:47,621 - py.warnings - WARNING - /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.14/site-packages/romancal/pipeline/exposure_pipeline.py:96: UserWarning: on_disk is only supported for associations, ignoring on_disk
#   lib, input_type = open_dataset(
#
# 2026-09-19 19:46:47,735 - stpipe.step - INFO - Step dq_init running with args (<roman_datamodels.datamodels._datamodels.ScienceRawModel object at 0x30611bdd0>,).
# 2026-09-19 19:46:49,575 - romancal.dq_init.dq_initialization - INFO - Invalid guide window location: -999999, -999983, -999999, -999983
# 2026-09-19 19:47:27,804 - stpipe.step - INFO - Step dq_init done
# 2026-09-19 19:47:27,880 - stpipe.step - INFO - Step saturation running with args (<roman_datamodels.datamodels._datamodels.RampModel object at 0x306190450>,).
# 2026-09-19 19:47:27,882 - romancal.saturation.saturation_step - INFO - Using SATURATION reference file: /grp/crds/cache/references/roman/roman_wfi_saturation_0031.asdf
# 2026-09-19 19:48:18,559 - stcal.saturation.saturation - INFO - Detected 77602 saturated pixels
# 2026-09-19 19:48:18,610 - stcal.saturation.saturation - INFO - Detected 65648 A/D floor pixels
# 2026-09-19 19:48:18,626 - stpipe.step - INFO - Step saturation done
# 2026-09-19 19:48:18,740 - stpipe.step - INFO - Step refpix running with args (<roman_datamodels.datamodels._datamodels.RampModel object at 0x306190450>,).
# 2026-09-19 19:48:20,693 - py.warnings - WARNING - /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.14/site-packages/romancal/refpix/_data.py:398: RuntimeWarning: invalid value encountered in divide
#   kern = (cov / mask_conv).reshape(rows, columns)
#
# 2026-09-19 19:51:48,130 - stpipe.step - INFO - Step refpix done
# 2026-09-19 19:51:48,205 - stpipe.step - INFO - Step dark_decay running with args (<roman_datamodels.datamodels._datamodels.RampModel object at 0x306190450>,).
# 2026-09-19 19:51:48,917 - romancal.dark_decay.dark_decay_step - INFO - Using DARKDECAYSIGNAL reference file: /grp/crds/cache/references/roman/roman_wfi_darkdecaysignal_0001.asdf
# 2026-09-19 19:51:48,985 - py.warnings - WARNING - /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.14/site-packages/asdf/_asdf.py:308: AsdfPackageVersionWarning: File 'file:///grp/crds/cache/references/roman/roman_wfi_darkdecaysignal_0001.asdf'was created with extension URI 'asdf://stsci.edu/datamodels/roman/extensions/static-1.1.0' (from package roman_datamodels==0.27.0), which is not currently installed
#   warnings.warn(msg, AsdfPackageVersionWarning)
#
# 2026-09-19 19:51:53,742 - stpipe.step - INFO - Step dark_decay done
# 2026-09-19 19:51:53,827 - stpipe.step - INFO - Step wfi18_transient running with args (<roman_datamodels.datamodels._datamodels.RampModel object at 0x306190450>,).
# 2026-09-19 19:51:53,829 - stpipe.step - INFO - Step wfi18_transient done
# 2026-09-19 19:51:53,921 - stpipe.step - INFO - Step linearity running with args (<roman_datamodels.datamodels._datamodels.RampModel object at 0x306190450>,).
# 2026-09-19 19:51:54,233 - romancal.linearity.linearity_step - INFO - Using LINEARITY reference file: /grp/crds/cache/references/roman/roman_wfi_linearity_0039.asdf
# 2026-09-19 19:51:54,239 - romancal.linearity.linearity_step - INFO - Using INVERSELINEARITY reference file: /grp/crds/cache/references/roman/roman_wfi_inverselinearity_0042.asdf
# 2026-09-19 19:51:54,244 - romancal.linearity.linearity_step - INFO - Using INTEGRALNONLINEARITY reference file: /grp/crds/cache/references/roman/roman_wfi_integralnonlinearity_0003.asdf
# 2026-09-19 19:51:55,427 - py.warnings - WARNING - /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.14/site-packages/asdf/_asdf.py:308: AsdfPackageVersionWarning: File 'file:///grp/crds/cache/references/roman/roman_wfi_integralnonlinearity_0003.asdf'was created with extension URI 'asdf://stsci.edu/datamodels/roman/extensions/static-1.1.0' (from package roman_datamodels==0.27.0), which is not currently installed
#   warnings.warn(msg, AsdfPackageVersionWarning)
#
# 2026-09-19 19:52:01,370 - py.warnings - WARNING - /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.14/site-packages/asdf/_asdf.py:308: AsdfPackageVersionWarning: File 'file:///grp/crds/cache/references/roman/roman_wfi_linearity_0039.asdf'was created with extension URI 'asdf://stsci.edu/datamodels/roman/extensions/static-1.0.0' (from package roman_datamodels==0.27.0), which is not currently installed
#   warnings.warn(msg, AsdfPackageVersionWarning)
#
# 2026-09-19 19:52:02,161 - py.warnings - WARNING - /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.14/site-packages/asdf/_asdf.py:308: AsdfPackageVersionWarning: File 'file:///grp/crds/cache/references/roman/roman_wfi_inverselinearity_0042.asdf'was created with extension URI 'asdf://stsci.edu/datamodels/roman/extensions/static-1.0.0' (from package roman_datamodels==0.27.0), which is not currently installed
#   warnings.warn(msg, AsdfPackageVersionWarning)
#
# 2026-09-19 19:58:13,009 - py.warnings - WARNING - /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.14/site-packages/stcal/linearity/linearity.py:494: RuntimeWarning: overflow encountered in cast
#   data[i] = np.where(resultant_saturated, data[i], corrected_resultant)
#
# 2026-09-19 19:59:09,433 - romancal.linearity.linearity_step - WARNING - Flagged 629 spurious values outside remotely plausible range.
# 2026-09-19 19:59:09,445 - stpipe.step - INFO - Step linearity done
# 2026-09-19 19:59:09,521 - stpipe.step - INFO - Step rampfit running with args (<roman_datamodels.datamodels._datamodels.RampModel object at 0x306190450>,).
# 2026-09-19 19:59:09,695 - romancal.ramp_fitting.ramp_fit_step - INFO - Using READNOISE reference file: /grp/crds/cache/references/roman/roman_wfi_readnoise_0051.asdf
# 2026-09-19 19:59:11,008 - romancal.ramp_fitting.ramp_fit_step - INFO - Using GAIN reference file: /grp/crds/cache/references/roman/roman_wfi_gain_0044.asdf
# 2026-09-19 19:59:12,150 - romancal.ramp_fitting.ramp_fit_step - INFO - Number of resultants: 10
# 2026-09-19 20:01:55,149 - py.warnings - WARNING - /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.14/site-packages/romancal/ramp_fitting/ramp_fit_step.py:489: RuntimeWarning: overflow encountered in cast
#   im.chisq = image_info["chisq"][4:-4, 4:-4].copy().astype("float16")
#
# 2026-09-19 20:01:55,150 - romancal.ramp_fitting.ramp_fit_step - INFO - Number of resultants: 10
# 2026-09-19 20:01:56,452 - stpipe.step - INFO - Step rampfit done
# 2026-09-19 20:01:56,539 - stpipe.step - INFO - Step dark_current running with args (<roman_datamodels.datamodels._datamodels.ImageModel object at 0x306182cf0>,).
# 2026-09-19 20:01:56,826 - romancal.dark_current.dark_current_step - INFO - Using DARK reference file: /grp/crds/cache/references/roman/roman_wfi_dark_0627.asdf
# 2026-09-19 20:01:58,597 - py.warnings - WARNING - /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.14/site-packages/asdf/_asdf.py:308: AsdfPackageVersionWarning: File 'file:///grp/crds/cache/references/roman/roman_wfi_dark_0627.asdf'was created with extension URI 'asdf://stsci.edu/datamodels/roman/extensions/static-1.1.0' (from package roman_datamodels==0.27.0), which is not currently installed
#   warnings.warn(msg, AsdfPackageVersionWarning)
#
# 2026-09-19 20:03:11,838 - stpipe.step - INFO - Step dark_current done
# 2026-09-19 20:03:11,909 - stpipe.step - INFO - Step assign_wcs running with args (<roman_datamodels.datamodels._datamodels.ImageModel object at 0x306182cf0>,).
# 2026-09-19 20:03:11,910 - romancal.assign_wcs.assign_wcs_step - INFO - reftype, distortion
# 2026-09-19 20:03:12,505 - romancal.assign_wcs.assign_wcs_step - INFO - Using reference files: {'distortion': '/grp/crds/cache/references/roman/roman_wfi_distortion_0014.asdf'} for assign_wcs
# 2026-09-19 20:03:12,652 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  269.986945913 65.974265020 269.986740071 66.097228517 269.676782731 66.097195577 269.680114248 65.974342004
# 2026-09-19 20:03:12,652 - romancal.assign_wcs.assign_wcs - INFO - S_REGION VALUES: POLYGON ICRS  269.986945913 65.974265020 269.986740071 66.097228517 269.676782731 66.097195577 269.680114248 65.974342004
# 2026-09-19 20:03:12,652 - romancal.assign_wcs.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  269.986945913 65.974265020 269.986740071 66.097228517 269.676782731 66.097195577 269.680114248 65.974342004
# 2026-09-19 20:03:13,237 - stpipe.step - INFO - Step assign_wcs done
# 2026-09-19 20:03:13,310 - stpipe.step - INFO - Step photom running with args (<roman_datamodels.datamodels._datamodels.ImageModel object at 0x306182cf0>,).
# 2026-09-19 20:03:13,523 - romancal.photom.photom - INFO - photmjsr value: 0.7367810113020512
# 2026-09-19 20:03:13,523 - romancal.photom.photom - INFO - uncertainty value: 0.02866405239530676
# 2026-09-19 20:03:14,112 - stpipe.step - INFO - Step photom done
# 2026-09-19 20:03:14,208 - stpipe.step - INFO - Step flatfield running with args (<roman_datamodels.datamodels._datamodels.ImageModel object at 0x306182cf0>,).
# 2026-09-19 20:04:43,847 - stpipe.step - INFO - Step flatfield done
# 2026-09-19 20:04:43,919 - stpipe.step - INFO - Step source_catalog running with args (<roman_datamodels.datamodels._datamodels.ImageModel object at 0x306182cf0>,).
# 2026-09-19 20:04:44,533 - romancal.source_catalog.source_catalog_step - INFO - Using ePSF reference file: /grp/crds/cache/references/roman/roman_wfi_epsf_0182.asdf
# 2026-09-19 20:04:45,836 - py.warnings - WARNING - /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.14/site-packages/asdf/_asdf.py:308: AsdfPackageVersionWarning: File 'file:///grp/crds/cache/references/roman/roman_wfi_epsf_0182.asdf'was created with extension URI 'asdf://stsci.edu/datamodels/roman/extensions/static-1.0.0' (from package roman_datamodels==0.27.0), which is not currently installed
#   warnings.warn(msg, AsdfPackageVersionWarning)
#
# 2026-09-19 20:05:06,396 - romancal.source_catalog.psf - INFO - Performed jitter convolution.  Image kernel: (8, 8, 0) Reference kernel: (0, 0, 0)
# 2026-09-19 20:05:06,567 - romancal.source_catalog.source_catalog_step - INFO - Calculating and subtracting background
# 2026-09-19 20:05:09,549 - romancal.source_catalog.source_catalog_step - INFO - Creating detection image
# 2026-09-19 20:05:10,489 - romancal.source_catalog.source_catalog_step - INFO - Detecting sources
# 2026-09-19 20:05:12,630 - romancal.source_catalog._detection - INFO - Detected 198 sources
# 2026-09-19 20:05:12,632 - romancal.source_catalog.source_catalog_step - INFO - Creating ee_fractions model
# 2026-09-19 20:05:13,026 - py.warnings - WARNING - /opt/anaconda3/envs/roman-data-workshop-env/lib/python3.14/site-packages/asdf/_asdf.py:308: AsdfPackageVersionWarning: File 'file:///grp/crds/cache/references/roman/roman_wfi_apcorr_0020.asdf'was created with extension URI 'asdf://stsci.edu/datamodels/roman/extensions/static-1.1.0' (from package roman_datamodels==0.30.0), which is not currently installed
#   warnings.warn(msg, AsdfPackageVersionWarning)
#
# 2026-09-19 20:05:13,076 - romancal.source_catalog.source_catalog_step - INFO - Creating source catalog
# 2026-09-19 20:05:13,112 - romancal.source_catalog._source_catalog - INFO - Calculating segment properties
# 2026-09-19 20:05:13,211 - romancal.source_catalog._source_catalog - INFO - Calculating aperture photometry
# 2026-09-19 20:05:13,275 - romancal.source_catalog._source_catalog - INFO - Calculating DAOFind properties
# 2026-09-19 20:05:13,413 - romancal.source_catalog._source_catalog - INFO - Calculating nearest neighbor properties
# 2026-09-19 20:05:13,414 - romancal.source_catalog._source_catalog - INFO - Calculating PSF photometry
# 2026-09-19 20:05:13,415 - romancal.source_catalog.psf - INFO - Integrating over the native pixel scale.
# 2026-09-19 20:05:14,183 - romancal.source_catalog._source_catalog - WARNING - meta.wcsinfo missing skycell_name/pixel_scale_ref; flagged_spatial_id will be zero.
# 2026-09-19 20:05:31,113 - stpipe.step - INFO - Step source_catalog done
# 2026-09-19 20:05:31,188 - stpipe.step - INFO - Step tweakreg running with args (<romancal.datamodels.library.ModelLibrary object at 0x304ade510>,).
# 2026-09-19 20:05:31,189 - romancal.tweakreg.tweakreg_step - INFO - Number of image groups to be aligned: 1.
# 2026-09-19 20:05:31,189 - romancal.tweakreg.tweakreg_step - INFO - Image groups:
# 2026-09-19 20:05:31,189 - romancal.tweakreg.tweakreg_step - INFO -   00001010010010010010001
# 2026-09-19 20:05:31,191 - romancal.tweakreg.tweakreg_step - INFO - All source catalogs will be saved to: /Users/phuwe/jupyter/roman-data-workshop/05-Intro_Roman_Pipeline
# 2026-09-19 20:05:31,191 - romancal.tweakreg.tweakreg_step - INFO - Using in-memory tweakreg catalog from meta.source_catalog.tweakreg_catalog for r0000101001001001001_0001_wfi01_f158_uncal.asdf.
# 2026-09-19 20:05:31,195 - romancal.tweakreg.tweakreg_step - INFO - Using 194 sources from r0000101001001001001_0001_wfi01_f158_uncal.asdf.
# 2026-09-19 20:05:33,236 - tweakwcs.imalign - INFO -
# 2026-09-19 20:05:33,237 - tweakwcs.imalign - INFO - ***** tweakwcs.imalign.align_wcs() started on 2026-09-19 20:05:33.236158
# 2026-09-19 20:05:33,237 - tweakwcs.imalign - INFO -       Version 0.9.2
# 2026-09-19 20:05:33,237 - tweakwcs.imalign - INFO -
# 2026-09-19 20:05:33,305 - tweakwcs.imalign - INFO - Aligning image catalog 'GROUP ID: 987654' to the reference catalog.
# 2026-09-19 20:05:33,330 - tweakwcs.matchutils - INFO - Matching sources from 'r0000101001001001001_0001_wfi01_f158_uncal' catalog with sources from the reference 'GAIADR3_S3' catalog.
# 2026-09-19 20:05:33,330 - tweakwcs.matchutils - INFO - Computing initial guess for X and Y shifts...
# 2026-09-19 20:05:33,333 - tweakwcs.matchutils - INFO - Found initial X and Y shifts of 0.0118334, 0.0118334 (arcsec) with significance of 107 and 107 matches.
# 2026-09-19 20:05:33,333 - tweakwcs.wcsimage - INFO - Found 107 matches for 'GROUP ID: 987654'...
# 2026-09-19 20:05:33,334 - tweakwcs.linearfit - INFO - Performing 'general' fit
# 2026-09-19 20:05:33,335 - tweakwcs.wcsimage - INFO - Computed 'general' fit for 'GROUP ID: 987654':
# 2026-09-19 20:05:33,335 - tweakwcs.wcsimage - INFO - XSH: -0.000698915  YSH: 0.000496465    PROPER ROT: 3.58902e-05
# 2026-09-19 20:05:33,336 - tweakwcs.wcsimage - INFO - <ROT>: 3.58902e-05  SKEW: 9.56886e-05    ROT_X: -1.19541e-05  ROT_Y: 8.37345e-05
# 2026-09-19 20:05:33,336 - tweakwcs.wcsimage - INFO - <SCALE>: 1  SCALE_X: 1  SCALE_Y: 1
# 2026-09-19 20:05:33,336 - tweakwcs.wcsimage - INFO -
# 2026-09-19 20:05:33,336 - tweakwcs.wcsimage - INFO - FIT RMSE: 0.00137844   FIT MAE: 0.00114682
# 2026-09-19 20:05:33,337 - tweakwcs.wcsimage - INFO - Final solution based on 104 objects.
# 2026-09-19 20:05:33,363 - tweakwcs.imalign - INFO -
# 2026-09-19 20:05:33,363 - tweakwcs.imalign - INFO - ***** tweakwcs.imalign.align_wcs() ended on 2026-09-19 20:05:33.363018
# 2026-09-19 20:05:33,363 - tweakwcs.imalign - INFO - ***** tweakwcs.imalign.align_wcs() TOTAL RUN TIME: 0:00:00.126860
# 2026-09-19 20:05:33,364 - tweakwcs.imalign - INFO -
# 2026-09-19 20:05:33,367 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  269.986945426 65.974265118 269.986740024 66.097228722 269.676782263 66.097195755 269.680113345 65.974342075
# 2026-09-19 20:05:33,368 - romancal.assign_wcs.assign_wcs - INFO - S_REGION VALUES: POLYGON ICRS  269.986945426 65.974265118 269.986740024 66.097228722 269.676782263 66.097195755 269.680113345 65.974342075
# 2026-09-19 20:05:33,368 - romancal.assign_wcs.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  269.986945426 65.974265118 269.986740024 66.097228722 269.676782263 66.097195755 269.680113345 65.974342075
# 2026-09-19 20:05:33,961 - stpipe.step - INFO - Step tweakreg done
# 2026-09-19 20:05:33,973 - romancal.pipeline.exposure_pipeline - INFO - Roman exposure calibration pipeline ending...
# 2026-09-19 20:05:34,651 - stpipe.step - INFO - Saved model in r0000101001001001001_0001_wfi01_f158_wcs.asdf
# 2026-09-19 20:05:35,178 - stpipe.step - INFO - Saved model in r0000101001001001001_0001_wfi01_f158_cal.asdf
# 2026-09-19 20:05:35,510 - stpipe.step - INFO - Saved model in r0000101001001001001_0001_wfi01_f158_cat.parquet
# 2026-09-19 20:05:35,677 - stpipe.step - INFO - Saved model in r0000101001001001001_0001_wfi01_f158_segm.asdf
# 2026-09-19 20:05:35,678 - stpipe.step - INFO - Step ExposurePipeline done

# %% [markdown]
# **Alternatively:**
#
# ```
# out.save(<filename.asdf>)
# ```

# %% [markdown]
# In this mode the call to `ExposurePipeline` saves the product to a file with the same root name and a suffix of **cal.asdf**.

# %% [markdown]
# #### Running individual steps
#
# Individual steps can be run in the same way. For example, running `assign_wcs` on the resultant `cal` file.
#
# All steps can be imported from a common namespace `romancal.step`. The input to each step
# is a file name or a data model and the output is a data model. Data models are returned in memory when running in Python.

# %%
from romancal.step import AssignWcsStep

out_model = AssignWcsStep.call('r0000101001001001001_0001_wfi01_f158_cal.asdf')
# Out:
# 2026-09-19 20:05:35,809 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-09-19 20:05:35,898 - stpipe.step - INFO - Step AssignWcsStep running with args ('r0000101001001001001_0001_wfi01_f158_cal.asdf',).
# 2026-09-19 20:05:35,899 - stpipe.step - INFO - Step AssignWcsStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: None
#   output_ext: .asdf
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   update_version: False
# 2026-09-19 20:05:35,976 - romancal.assign_wcs.assign_wcs_step - INFO - reftype, distortion
# 2026-09-19 20:05:36,118 - romancal.assign_wcs.assign_wcs_step - INFO - Using reference files: {'distortion': '/grp/crds/cache/references/roman/roman_wfi_distortion_0014.asdf'} for assign_wcs
# 2026-09-19 20:05:36,170 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  269.986945913 65.974265020 269.986740071 66.097228517 269.676782731 66.097195577 269.680114248 65.974342004
# 2026-09-19 20:05:36,170 - romancal.assign_wcs.assign_wcs - INFO - S_REGION VALUES: POLYGON ICRS  269.986945913 65.974265020 269.986740071 66.097228517 269.676782731 66.097195577 269.680114248 65.974342004
# 2026-09-19 20:05:36,171 - romancal.assign_wcs.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  269.986945913 65.974265020 269.986740071 66.097228517 269.676782731 66.097195577 269.680114248 65.974342004
# 2026-09-19 20:05:36,850 - romancal.stpipe.core - INFO - Results used CRDS context: roman_0066.pmap
# 2026-09-19 20:05:36,850 - stpipe.step - INFO - Step AssignWcsStep done

# %%
out_model.save('r002_assign_wcs.asdf')
# Out:
# PosixPath('r002_assign_wcs.asdf')

# %% [markdown]
# The calls above used reference files in CRDS. **One can pass local reference files to a step or a pipeline.** For example, running assign_wcs with a custom `distortion` file called "new_distortion.asdf" in the current directory:

# %%
out_model = AssignWcsStep.call('../data/r0000101001001001001_0001_wfi01_f158_cal.asdf', override_distortion="../data/new_distortion.asdf")
# Out:
# 2026-09-19 20:05:37,520 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-09-19 20:05:37,612 - stpipe.step - INFO - Step AssignWcsStep running with args ('../data/r0000101001001001001_0001_wfi01_f158_cal.asdf',).
# 2026-09-19 20:05:37,614 - stpipe.step - INFO - Step AssignWcsStep parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: None
#   output_ext: .asdf
#   output_use_model: False
#   output_use_index: True
#   save_results: False
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   update_version: False
# 2026-09-19 20:05:37,694 - romancal.assign_wcs.assign_wcs_step - INFO - reftype, distortion
# 2026-09-19 20:05:37,694 - romancal.assign_wcs.assign_wcs_step - INFO - Using reference files: {'distortion': '/Users/phuwe/jupyter/roman-data-workshop/data/new_distortion.asdf'} for assign_wcs
# 2026-09-19 20:05:37,728 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  269.986945913 65.974265020 269.986740071 66.097228517 269.676782731 66.097195577 269.680114248 65.974342004
# 2026-09-19 20:05:37,734 - romancal.assign_wcs.assign_wcs - INFO - S_REGION VALUES: POLYGON ICRS  269.986945913 65.974265020 269.986740071 66.097228517 269.676782731 66.097195577 269.680114248 65.974342004
# 2026-09-19 20:05:37,735 - romancal.assign_wcs.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  269.986945913 65.974265020 269.986740071 66.097228517 269.676782731 66.097195577 269.680114248 65.974342004
# 2026-09-19 20:05:38,368 - romancal.stpipe.core - INFO - Results used CRDS context: roman_0066.pmap
# 2026-09-19 20:05:38,369 - stpipe.step - INFO - Step AssignWcsStep done

# %% [markdown]
# #### Running from the command line
#
# DMS runs the cal pipeline using the command line interface. The general syntax is
#
# ```
# % strun romancal.pipeline.ExposurePipeline <input_file>
# ```
#
# or using an alias
#
# ```
# % strun roman_elp <input_file>
# ```

# %% [markdown]
# **Running the pipeline with local reference files**
#
# Again, the above call uses reference files stored in CRDS. To use local reference files
#
# ```
# % strun romancal.pipeline.ExposurePipeline <input_file> --steps.flat.override_flat=myflat.asdf
# ```
#
# ```
# % strun romancal.step.FlatStep <input_file> --override_flat=myflat.asdf
# ```

# %% [markdown]
# **Skipping a step in the pipeline**
#
# ```
# % strun romancal.pipeline.ExposurePipeline <input_file> --steps.linearity.skip=True
# ```

# %% [markdown]
# **List the parameters for a step**
#
# To display a list of the parameters that are accepted for a given Step class, pass the `-h` parameter, and the name of a Step class or parameter file:
#
# ```
# % strun -h romancal.step.RampFitStep
#
# usage: strun [-h] [--debug] [--save-parameters SAVE_PARAMETERS] [--disable-crds-steppars] [--logcfg LOGCFG] [--verbose]
#              [--log-level LOG_LEVEL] [--log-file LOG_FILE] [--log-stream LOG_STREAM] [--pre_hooks ] [--post_hooks ]
#              [--output_file ] [--output_dir ] [--output_ext ] [--output_use_model ] [--output_use_index ] [--save_results ]
#              [--skip ] [--suffix ] [--search_output_file ] [--input_dir ] [--update_version ] [--algorithm ]
#              [--rejection_threshold ] [--use_ramp_jump_detection ] [--threshold_intercept ] [--threshold_constant ]
#              [--include_var_rnoise ] [--record_jumps ] [--maximum_cores ] [--expand_large_events ] [--min_sat_area ]
#              [--min_jump_area ] [--expand_factor ] [--sat_required_snowball ] [--min_sat_radius_extend ] [--sat_expand ]
#              [--edge_size ] [--override_readnoise ] [--override_gain ]
#              cfg_file_or_class [args ...]
#
# This step fits a straight line to the value of counts vs. time to determine the mean count rate for each pixel.
#
# positional arguments:
#   cfg_file_or_class     The configuration file or Python class to run
#   args                  arguments to pass to step
#
# options:
#   -h, --help            show this help message and exit
#   --debug               When an exception occurs, invoke the Python debugger, pdb
#   --save-parameters SAVE_PARAMETERS
#                         Save step parameters to specified file
#   --disable-crds-steppars
#                         Disable retrieval of step parameter references files from CRDS
#   --logcfg LOGCFG       DEPRECATED: The logging configuration file to load. Ignored if verbose or other log arguments are
#                         set.
#   --verbose, -v         Turn on all logging messages
#   --log-level LOG_LEVEL
#                         Log level (DEBUG, INFO, WARNING, ERROR, CRITICAL). Ignored if 'verbose' is specified.
#   --log-file LOG_FILE   Full path to a file name to record log messages
#   --log-stream LOG_STREAM
#                         Log stream for terminal messages (stdout, stderr, or null).
#   --pre_hooks           List of Step classes to run before step [default=list]
#   --post_hooks          List of Step classes to run after step [default=list]
#   --output_file         File to save output to.
#   --output_dir          Directory path for output files (created if nonexistent)
#   --output_ext          Default type of output [default='.asdf']
#   --output_use_model    When saving use `DataModel.meta.filename` [default=False]
#   --output_use_index    Append index. [default=True]
#   --save_results        Force save results [default=False]
#   --skip                Skip this step [default=False]
#   --suffix              Default suffix of results [default='rampfit']
#   --search_output_file
#                         Use outputfile define in parent step [default=True]
#   --input_dir           Input directory
#   --update_version      Update old versions of datamodels to newest version [default=False]
#   --algorithm           Algorithm to use to fit. Note: `ols_cas22` is deprecated and will be removed in a future version
#                         ['ols_cas22', 'likely', default='likely']
#   --rejection_threshold
#                         CR sigma rejection threshold [default=4.5,min=0]
#   --use_ramp_jump_detection
#                         Use jump detection during ramp fitting [default=True]
#   --threshold_intercept
#                         Override the intercept parameter for the threshold function in the jump detection algorithm.
#   --threshold_constant
#                         Override the constant parameter for the threshold function in the jump detection algorithm.
#   --include_var_rnoise
#                         include var_rnoise in output (can be reconstructed from err and other variances) [default=False]
#   --record_jumps        record which resultant each jump was flagged in as a jump_indices extension (likely algorithm only)
#                         [default=True]
#   --maximum_cores       cores for multiprocessing. Can be an integer, 'half', 'quarter', or 'all' [default='1']
#   --expand_large_events
#                         Turns on Snowball detection [default=False]
#   --min_sat_area        minimum required area for the central saturation of snowballs [default=1.0]
#   --min_jump_area       minimum area to trigger large events processing [default=6.0]
#   --expand_factor       The expansion factor for the enclosing circles or ellipses [default=1.9]
#   --sat_required_snowball
#                         Require the center of snowballs to be saturated [default=True]
#   --min_sat_radius_extend
#                         The min radius of the sat core to trigger the extension of the core [default=0.5]
#   --sat_expand          Number of pixels to add to the radius of the saturated core of snowballs [default=2]
#   --edge_size           Distance from detector edge where a saturated core is not required for snowball detection [default=0]
#   --override_readnoise
#                         Override the readnoise reference file
#   --override_gain       Override the gain reference file
# ```

# %% [markdown]
# #### Calibration reference Data System (CRDS)
#
# CRDS is a Python library, set of command line programs, and family of web servers used to assign and manage the best reference files that are used to calibrate HST, JWST and Roman data.
#
# The primary function of CRDS is to assign best reference files to datasets so that they can be calibrated based upon CRDS rules.
#
# The CRDS User guide is available on the front page of the CRDS server.
#
# https://roman-crds.stsci.edu/static/users_guide/index.html

# %% [markdown]
# **Exercise:**
#
# Run the Roman Exposure Level pipeline on a Level 1 file .
#
# On the command line this is
#
# ```
# strun roman_elp r0000101001001001001_0001_wfi01_f158_uncal.asdf --steps.rampfit.save_results=true
# ```
